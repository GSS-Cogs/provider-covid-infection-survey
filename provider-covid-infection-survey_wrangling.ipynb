# %%
import pandas as pd

# %%
df = pd.read_excel(io="20230113covid19infectionsurveydatasetsengland.xlsx", sheet_name="1a", skiprows=4)

# %%
df
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# 134                                               1.73
# 135                                               2.01
# 136                                               2.20
# 137                                               4.52
# 138                                               4.02
#
#      95% Lower confidence/credible interval for percentage  \
# 0                                                 0.17
# 1                                                 0.16
# 2                                                 0.11
# 3                                                 0.05
# 4                                                 0.02
# ..                                                 ...
# 134                                               1.60
# 135                                               1.87
# 136                                               2.08
# 137                                               4.29
# 138                                               3.84
#
#      95% Upper confidence/credible interval for percentage  \
# 0                                                 0.41
# 1                                                 0.38
# 2                                                 0.46
# 3                                                 0.18
# 4                                                 0.12
# ..                                                 ...
# 134                                               1.86
# 135                                               2.15
# 136                                               2.32
# 137                                               4.76
# 138                                               4.19
#
#       Estimated average number of people testing positive for COVID-19  \
# 0                                               148000
# 1                                               137000
# 2                                               133000
# 3                                                53000
# 4                                                33000
# ..                                                 ...
# 134                                             941700
# 135                                            1095100
# 136                                            1197200
# 137                                            2463000
# 138                                            2189300
#
#      95% Lower confidence/credible interval for number  \
# 0                                                94000
# 1                                                85000
# 2                                                62000
# 3                                                25000
# 4                                                14000
# ..                                                 ...
# 134                                             874100
# 135                                            1022000
# 136                                            1135000
# 137                                            2338700
# 138                                            2094800
#
#      95% Upper confidence/credible interval for number  \
# 0                                               222000
# 1                                               208000
# 2                                               250000
# 3                                                99000
# 4                                                68000
# ..                                                 ...
# 134                                            1013600
# 135                                            1173500
# 136                                            1263900
# 137                                            2593200
# 138                                            2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 2                                             1 in 420
# 3                                           1 in 1,000
# 4                                           1 in 1,700
# ..                                                 ...
# 134                                            1 in 60
# 135                                            1 in 50
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 2                                           1 in 910
# 3                                         1 in 2,000
# 4                                         1 in 5,000
# ..                                               ...
# 134                                          1 in 60
# 135                                          1 in 55
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio
# 0                                           1 in 240
# 1                                           1 in 260
# 2                                           1 in 220
# 3                                           1 in 560
# 4                                           1 in 830
# ..                                               ...
# 134                                          1 in 55
# 135                                          1 in 45
# 136                                          1 in 45
# 137                                          1 in 20
# 138                                          1 in 25
#
# [139 rows x 10 columns]

# %%
df["Time period"]
# Out:
# 0              27 April 2020 to 10 May 2020
# 1                04 May 2020 to 17 May 2020
# 2                11 May 2020 to 24 May 2020
# 3                17 May 2020 to 30 May 2020
# 4               25 May 2020 to 07 June 2020
#                        ...
# 134    20 November 2022 to 26 November 2022
# 135    29 November 2022 to 05 December 2022
# 136    03 December 2022 to 09 December 2022
# 137    22 December 2022 to 28 December 2022
# 138     28 December 2022 to 03 January 2023
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ")
# Out:
# 0              [27 April 2020, 10 May 2020]
# 1                [04 May 2020, 17 May 2020]
# 2                [11 May 2020, 24 May 2020]
# 3                [17 May 2020, 30 May 2020]
# 4               [25 May 2020, 07 June 2020]
#                        ...
# 134    [20 November 2022, 26 November 2022]
# 135    [29 November 2022, 05 December 2022]
# 136    [03 December 2022, 09 December 2022]
# 137    [22 December 2022, 28 December 2022]
# 138     [28 December 2022, 03 January 2023]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ")[0]
# Out:
# ['27 April 2020', '10 May 2020']

# %%
df["Time period"].str.split(" to ").apply(lambda x: [y[0] for y in list(x)])
# Out:
# 0      [2, 1]
# 1      [0, 1]
# 2      [1, 2]
# 3      [1, 3]
# 4      [2, 0]
#         ...
# 134    [2, 2]
# 135    [2, 0]
# 136    [0, 0]
# 137    [2, 2]
# 138    [2, 0]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ").apply(lambda x: [y[0] for y in list(x)])
# Out:
# 0      [2, 1]
# 1      [0, 1]
# 2      [1, 2]
# 3      [1, 3]
# 4      [2, 0]
#         ...
# 134    [2, 2]
# 135    [2, 0]
# 136    [0, 0]
# 137    [2, 2]
# 138    [2, 0]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ").apply(lambda x: [y[0] for y in x])
# Out:
# 0      [2, 1]
# 1      [0, 1]
# 2      [1, 2]
# 3      [1, 3]
# 4      [2, 0]
#         ...
# 134    [2, 2]
# 135    [2, 0]
# 136    [0, 0]
# 137    [2, 2]
# 138    [2, 0]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ")
# Out:
# 0              [27 April 2020, 10 May 2020]
# 1                [04 May 2020, 17 May 2020]
# 2                [11 May 2020, 24 May 2020]
# 3                [17 May 2020, 30 May 2020]
# 4               [25 May 2020, 07 June 2020]
#                        ...
# 134    [20 November 2022, 26 November 2022]
# 135    [29 November 2022, 05 December 2022]
# 136    [03 December 2022, 09 December 2022]
# 137    [22 December 2022, 28 December 2022]
# 138     [28 December 2022, 03 January 2023]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ")[0]
# Out:
# ['27 April 2020', '10 May 2020']

# %%
df["Time period"].str.split(" to ", n=1)
# Out:
# 0              [27 April 2020, 10 May 2020]
# 1                [04 May 2020, 17 May 2020]
# 2                [11 May 2020, 24 May 2020]
# 3                [17 May 2020, 30 May 2020]
# 4               [25 May 2020, 07 June 2020]
#                        ...
# 134    [20 November 2022, 26 November 2022]
# 135    [29 November 2022, 05 December 2022]
# 136    [03 December 2022, 09 December 2022]
# 137    [22 December 2022, 28 December 2022]
# 138     [28 December 2022, 03 January 2023]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ", n=0)
# Out:
# 0              [27 April 2020, 10 May 2020]
# 1                [04 May 2020, 17 May 2020]
# 2                [11 May 2020, 24 May 2020]
# 3                [17 May 2020, 30 May 2020]
# 4               [25 May 2020, 07 June 2020]
#                        ...
# 134    [20 November 2022, 26 November 2022]
# 135    [29 November 2022, 05 December 2022]
# 136    [03 December 2022, 09 December 2022]
# 137    [22 December 2022, 28 December 2022]
# 138     [28 December 2022, 03 January 2023]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ", expand=True)
# Out:
#                     0                 1
# 0       27 April 2020       10 May 2020
# 1         04 May 2020       17 May 2020
# 2         11 May 2020       24 May 2020
# 3         17 May 2020       30 May 2020
# 4         25 May 2020      07 June 2020
# ..                ...               ...
# 134  20 November 2022  26 November 2022
# 135  29 November 2022  05 December 2022
# 136  03 December 2022  09 December 2022
# 137  22 December 2022  28 December 2022
# 138  28 December 2022   03 January 2023
#
# [139 rows x 2 columns]

# %%
df.join(df["Time period"].str.split(" to ", expand=True))
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# 134                                               1.73
# 135                                               2.01
# 136                                               2.20
# 137                                               4.52
# 138                                               4.02
#
#      95% Lower confidence/credible interval for percentage  \
# 0                                                 0.17
# 1                                                 0.16
# 2                                                 0.11
# 3                                                 0.05
# 4                                                 0.02
# ..                                                 ...
# 134                                               1.60
# 135                                               1.87
# 136                                               2.08
# 137                                               4.29
# 138                                               3.84
#
#      95% Upper confidence/credible interval for percentage  \
# 0                                                 0.41
# 1                                                 0.38
# 2                                                 0.46
# 3                                                 0.18
# 4                                                 0.12
# ..                                                 ...
# 134                                               1.86
# 135                                               2.15
# 136                                               2.32
# 137                                               4.76
# 138                                               4.19
#
#       Estimated average number of people testing positive for COVID-19  \
# 0                                               148000
# 1                                               137000
# 2                                               133000
# 3                                                53000
# 4                                                33000
# ..                                                 ...
# 134                                             941700
# 135                                            1095100
# 136                                            1197200
# 137                                            2463000
# 138                                            2189300
#
#      95% Lower confidence/credible interval for number  \
# 0                                                94000
# 1                                                85000
# 2                                                62000
# 3                                                25000
# 4                                                14000
# ..                                                 ...
# 134                                             874100
# 135                                            1022000
# 136                                            1135000
# 137                                            2338700
# 138                                            2094800
#
#      95% Upper confidence/credible interval for number  \
# 0                                               222000
# 1                                               208000
# 2                                               250000
# 3                                                99000
# 4                                                68000
# ..                                                 ...
# 134                                            1013600
# 135                                            1173500
# 136                                            1263900
# 137                                            2593200
# 138                                            2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 2                                             1 in 420
# 3                                           1 in 1,000
# 4                                           1 in 1,700
# ..                                                 ...
# 134                                            1 in 60
# 135                                            1 in 50
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 2                                           1 in 910
# 3                                         1 in 2,000
# 4                                         1 in 5,000
# ..                                               ...
# 134                                          1 in 60
# 135                                          1 in 55
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio                 0  \
# 0                                           1 in 240     27 April 2020
# 1                                           1 in 260       04 May 2020
# 2                                           1 in 220       11 May 2020
# 3                                           1 in 560       17 May 2020
# 4                                           1 in 830       25 May 2020
# ..                                               ...               ...
# 134                                          1 in 55  20 November 2022
# 135                                          1 in 45  29 November 2022
# 136                                          1 in 45  03 December 2022
# 137                                          1 in 20  22 December 2022
# 138                                          1 in 25  28 December 2022
#
#                     1
# 0         10 May 2020
# 1         17 May 2020
# 2         24 May 2020
# 3         30 May 2020
# 4        07 June 2020
# ..                ...
# 134  26 November 2022
# 135  05 December 2022
# 136  09 December 2022
# 137  28 December 2022
# 138   03 January 2023
#
# [139 rows x 12 columns]

# %%
df2 = df.join(df["Time period"].str.split(" to ", expand=True))

# %%
df2
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# 134                                               1.73
# 135                                               2.01
# 136                                               2.20
# 137                                               4.52
# 138                                               4.02
#
#      95% Lower confidence/credible interval for percentage  \
# 0                                                 0.17
# 1                                                 0.16
# 2                                                 0.11
# 3                                                 0.05
# 4                                                 0.02
# ..                                                 ...
# 134                                               1.60
# 135                                               1.87
# 136                                               2.08
# 137                                               4.29
# 138                                               3.84
#
#      95% Upper confidence/credible interval for percentage  \
# 0                                                 0.41
# 1                                                 0.38
# 2                                                 0.46
# 3                                                 0.18
# 4                                                 0.12
# ..                                                 ...
# 134                                               1.86
# 135                                               2.15
# 136                                               2.32
# 137                                               4.76
# 138                                               4.19
#
#       Estimated average number of people testing positive for COVID-19  \
# 0                                               148000
# 1                                               137000
# 2                                               133000
# 3                                                53000
# 4                                                33000
# ..                                                 ...
# 134                                             941700
# 135                                            1095100
# 136                                            1197200
# 137                                            2463000
# 138                                            2189300
#
#      95% Lower confidence/credible interval for number  \
# 0                                                94000
# 1                                                85000
# 2                                                62000
# 3                                                25000
# 4                                                14000
# ..                                                 ...
# 134                                             874100
# 135                                            1022000
# 136                                            1135000
# 137                                            2338700
# 138                                            2094800
#
#      95% Upper confidence/credible interval for number  \
# 0                                               222000
# 1                                               208000
# 2                                               250000
# 3                                                99000
# 4                                                68000
# ..                                                 ...
# 134                                            1013600
# 135                                            1173500
# 136                                            1263900
# 137                                            2593200
# 138                                            2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 2                                             1 in 420
# 3                                           1 in 1,000
# 4                                           1 in 1,700
# ..                                                 ...
# 134                                            1 in 60
# 135                                            1 in 50
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 2                                           1 in 910
# 3                                         1 in 2,000
# 4                                         1 in 5,000
# ..                                               ...
# 134                                          1 in 60
# 135                                          1 in 55
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio                 0  \
# 0                                           1 in 240     27 April 2020
# 1                                           1 in 260       04 May 2020
# 2                                           1 in 220       11 May 2020
# 3                                           1 in 560       17 May 2020
# 4                                           1 in 830       25 May 2020
# ..                                               ...               ...
# 134                                          1 in 55  20 November 2022
# 135                                          1 in 45  29 November 2022
# 136                                          1 in 45  03 December 2022
# 137                                          1 in 20  22 December 2022
# 138                                          1 in 25  28 December 2022
#
#                     1
# 0         10 May 2020
# 1         17 May 2020
# 2         24 May 2020
# 3         30 May 2020
# 4        07 June 2020
# ..                ...
# 134  26 November 2022
# 135  05 December 2022
# 136  09 December 2022
# 137  28 December 2022
# 138   03 January 2023
#
# [139 rows x 12 columns]

# %%
df2.rename(columns={"0": "start_date", "1": "end_date"})
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# 134                                               1.73
# 135                                               2.01
# 136                                               2.20
# 137                                               4.52
# 138                                               4.02
#
#      95% Lower confidence/credible interval for percentage  \
# 0                                                 0.17
# 1                                                 0.16
# 2                                                 0.11
# 3                                                 0.05
# 4                                                 0.02
# ..                                                 ...
# 134                                               1.60
# 135                                               1.87
# 136                                               2.08
# 137                                               4.29
# 138                                               3.84
#
#      95% Upper confidence/credible interval for percentage  \
# 0                                                 0.41
# 1                                                 0.38
# 2                                                 0.46
# 3                                                 0.18
# 4                                                 0.12
# ..                                                 ...
# 134                                               1.86
# 135                                               2.15
# 136                                               2.32
# 137                                               4.76
# 138                                               4.19
#
#       Estimated average number of people testing positive for COVID-19  \
# 0                                               148000
# 1                                               137000
# 2                                               133000
# 3                                                53000
# 4                                                33000
# ..                                                 ...
# 134                                             941700
# 135                                            1095100
# 136                                            1197200
# 137                                            2463000
# 138                                            2189300
#
#      95% Lower confidence/credible interval for number  \
# 0                                                94000
# 1                                                85000
# 2                                                62000
# 3                                                25000
# 4                                                14000
# ..                                                 ...
# 134                                             874100
# 135                                            1022000
# 136                                            1135000
# 137                                            2338700
# 138                                            2094800
#
#      95% Upper confidence/credible interval for number  \
# 0                                               222000
# 1                                               208000
# 2                                               250000
# 3                                                99000
# 4                                                68000
# ..                                                 ...
# 134                                            1013600
# 135                                            1173500
# 136                                            1263900
# 137                                            2593200
# 138                                            2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 2                                             1 in 420
# 3                                           1 in 1,000
# 4                                           1 in 1,700
# ..                                                 ...
# 134                                            1 in 60
# 135                                            1 in 50
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 2                                           1 in 910
# 3                                         1 in 2,000
# 4                                         1 in 5,000
# ..                                               ...
# 134                                          1 in 60
# 135                                          1 in 55
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio                 0  \
# 0                                           1 in 240     27 April 2020
# 1                                           1 in 260       04 May 2020
# 2                                           1 in 220       11 May 2020
# 3                                           1 in 560       17 May 2020
# 4                                           1 in 830       25 May 2020
# ..                                               ...               ...
# 134                                          1 in 55  20 November 2022
# 135                                          1 in 45  29 November 2022
# 136                                          1 in 45  03 December 2022
# 137                                          1 in 20  22 December 2022
# 138                                          1 in 25  28 December 2022
#
#                     1
# 0         10 May 2020
# 1         17 May 2020
# 2         24 May 2020
# 3         30 May 2020
# 4        07 June 2020
# ..                ...
# 134  26 November 2022
# 135  05 December 2022
# 136  09 December 2022
# 137  28 December 2022
# 138   03 January 2023
#
# [139 rows x 12 columns]

# %%
df2 = df2.rename(columns={"0": "start_date", "1": "end_date"})

# %%
df2
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# 134                                               1.73
# 135                                               2.01
# 136                                               2.20
# 137                                               4.52
# 138                                               4.02
#
#      95% Lower confidence/credible interval for percentage  \
# 0                                                 0.17
# 1                                                 0.16
# 2                                                 0.11
# 3                                                 0.05
# 4                                                 0.02
# ..                                                 ...
# 134                                               1.60
# 135                                               1.87
# 136                                               2.08
# 137                                               4.29
# 138                                               3.84
#
#      95% Upper confidence/credible interval for percentage  \
# 0                                                 0.41
# 1                                                 0.38
# 2                                                 0.46
# 3                                                 0.18
# 4                                                 0.12
# ..                                                 ...
# 134                                               1.86
# 135                                               2.15
# 136                                               2.32
# 137                                               4.76
# 138                                               4.19
#
#       Estimated average number of people testing positive for COVID-19  \
# 0                                               148000
# 1                                               137000
# 2                                               133000
# 3                                                53000
# 4                                                33000
# ..                                                 ...
# 134                                             941700
# 135                                            1095100
# 136                                            1197200
# 137                                            2463000
# 138                                            2189300
#
#      95% Lower confidence/credible interval for number  \
# 0                                                94000
# 1                                                85000
# 2                                                62000
# 3                                                25000
# 4                                                14000
# ..                                                 ...
# 134                                             874100
# 135                                            1022000
# 136                                            1135000
# 137                                            2338700
# 138                                            2094800
#
#      95% Upper confidence/credible interval for number  \
# 0                                               222000
# 1                                               208000
# 2                                               250000
# 3                                                99000
# 4                                                68000
# ..                                                 ...
# 134                                            1013600
# 135                                            1173500
# 136                                            1263900
# 137                                            2593200
# 138                                            2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 2                                             1 in 420
# 3                                           1 in 1,000
# 4                                           1 in 1,700
# ..                                                 ...
# 134                                            1 in 60
# 135                                            1 in 50
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 2                                           1 in 910
# 3                                         1 in 2,000
# 4                                         1 in 5,000
# ..                                               ...
# 134                                          1 in 60
# 135                                          1 in 55
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio                 0  \
# 0                                           1 in 240     27 April 2020
# 1                                           1 in 260       04 May 2020
# 2                                           1 in 220       11 May 2020
# 3                                           1 in 560       17 May 2020
# 4                                           1 in 830       25 May 2020
# ..                                               ...               ...
# 134                                          1 in 55  20 November 2022
# 135                                          1 in 45  29 November 2022
# 136                                          1 in 45  03 December 2022
# 137                                          1 in 20  22 December 2022
# 138                                          1 in 25  28 December 2022
#
#                     1
# 0         10 May 2020
# 1         17 May 2020
# 2         24 May 2020
# 3         30 May 2020
# 4        07 June 2020
# ..                ...
# 134  26 November 2022
# 135  05 December 2022
# 136  09 December 2022
# 137  28 December 2022
# 138   03 January 2023
#
# [139 rows x 12 columns]

# %%
df2 = df2.rename(columns={0: "start_date", 1: "end_date"})

# %%
df2
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# 134                                               1.73
# 135                                               2.01
# 136                                               2.20
# 137                                               4.52
# 138                                               4.02
#
#      95% Lower confidence/credible interval for percentage  \
# 0                                                 0.17
# 1                                                 0.16
# 2                                                 0.11
# 3                                                 0.05
# 4                                                 0.02
# ..                                                 ...
# 134                                               1.60
# 135                                               1.87
# 136                                               2.08
# 137                                               4.29
# 138                                               3.84
#
#      95% Upper confidence/credible interval for percentage  \
# 0                                                 0.41
# 1                                                 0.38
# 2                                                 0.46
# 3                                                 0.18
# 4                                                 0.12
# ..                                                 ...
# 134                                               1.86
# 135                                               2.15
# 136                                               2.32
# 137                                               4.76
# 138                                               4.19
#
#       Estimated average number of people testing positive for COVID-19  \
# 0                                               148000
# 1                                               137000
# 2                                               133000
# 3                                                53000
# 4                                                33000
# ..                                                 ...
# 134                                             941700
# 135                                            1095100
# 136                                            1197200
# 137                                            2463000
# 138                                            2189300
#
#      95% Lower confidence/credible interval for number  \
# 0                                                94000
# 1                                                85000
# 2                                                62000
# 3                                                25000
# 4                                                14000
# ..                                                 ...
# 134                                             874100
# 135                                            1022000
# 136                                            1135000
# 137                                            2338700
# 138                                            2094800
#
#      95% Upper confidence/credible interval for number  \
# 0                                               222000
# 1                                               208000
# 2                                               250000
# 3                                                99000
# 4                                                68000
# ..                                                 ...
# 134                                            1013600
# 135                                            1173500
# 136                                            1263900
# 137                                            2593200
# 138                                            2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 2                                             1 in 420
# 3                                           1 in 1,000
# 4                                           1 in 1,700
# ..                                                 ...
# 134                                            1 in 60
# 135                                            1 in 50
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 2                                           1 in 910
# 3                                         1 in 2,000
# 4                                         1 in 5,000
# ..                                               ...
# 134                                          1 in 60
# 135                                          1 in 55
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio        start_date  \
# 0                                           1 in 240     27 April 2020
# 1                                           1 in 260       04 May 2020
# 2                                           1 in 220       11 May 2020
# 3                                           1 in 560       17 May 2020
# 4                                           1 in 830       25 May 2020
# ..                                               ...               ...
# 134                                          1 in 55  20 November 2022
# 135                                          1 in 45  29 November 2022
# 136                                          1 in 45  03 December 2022
# 137                                          1 in 20  22 December 2022
# 138                                          1 in 25  28 December 2022
#
#              end_date
# 0         10 May 2020
# 1         17 May 2020
# 2         24 May 2020
# 3         30 May 2020
# 4        07 June 2020
# ..                ...
# 134  26 November 2022
# 135  05 December 2022
# 136  09 December 2022
# 137  28 December 2022
# 138   03 January 2023
#
# [139 rows x 12 columns]

# %%
df2["start_date"]
# Out:
# 0         27 April 2020
# 1           04 May 2020
# 2           11 May 2020
# 3           17 May 2020
# 4           25 May 2020
#              ...
# 134    20 November 2022
# 135    29 November 2022
# 136    03 December 2022
# 137    22 December 2022
# 138    28 December 2022
# Name: start_date, Length: 139, dtype: object

# %%
pd.to_datetime(df2["start_date"])
# Out:
# 0     2020-04-27
# 1     2020-05-04
# 2     2020-05-11
# 3     2020-05-17
# 4     2020-05-25
#          ...
# 134   2022-11-20
# 135   2022-11-29
# 136   2022-12-03
# 137   2022-12-22
# 138   2022-12-28
# Name: start_date, Length: 139, dtype: datetime64[ns]

# %%
df2["start_date"] = pd.to_datetime(df2["start_date"])

# %%
df2["start_date"].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 134    2022
# 135    2022
# 136    2022
# 137    2022
# 138    2022
# Name: start_date, Length: 139, dtype: int64

# %%
df2["start_date"].dt.week
# Out:
# /var/folders/7k/w8wpn6jn6hx_s0h1xqgbvj040000gr/T/ipykernel_23206/4160652197.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2["start_date"].dt.week
# 0      18
# 1      19
# 2      20
# 3      20
# 4      22
#        ..
# 134    46
# 135    48
# 136    48
# 137    51
# 138    52
# Name: start_date, Length: 139, dtype: int64

# %%
df2["start_date_year"] = df2["start_date"].dt.year

# %%
df2["start_date_week"] = df2["start_date"].dt.week
# Out:
# /var/folders/7k/w8wpn6jn6hx_s0h1xqgbvj040000gr/T/ipykernel_23206/831258434.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2["start_date_week"] = df2["start_date"].dt.week

# %%
df2
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# 134                                               1.73
# 135                                               2.01
# 136                                               2.20
# 137                                               4.52
# 138                                               4.02
#
#      95% Lower confidence/credible interval for percentage  \
# 0                                                 0.17
# 1                                                 0.16
# 2                                                 0.11
# 3                                                 0.05
# 4                                                 0.02
# ..                                                 ...
# 134                                               1.60
# 135                                               1.87
# 136                                               2.08
# 137                                               4.29
# 138                                               3.84
#
#      95% Upper confidence/credible interval for percentage  \
# 0                                                 0.41
# 1                                                 0.38
# 2                                                 0.46
# 3                                                 0.18
# 4                                                 0.12
# ..                                                 ...
# 134                                               1.86
# 135                                               2.15
# 136                                               2.32
# 137                                               4.76
# 138                                               4.19
#
#       Estimated average number of people testing positive for COVID-19  \
# 0                                               148000
# 1                                               137000
# 2                                               133000
# 3                                                53000
# 4                                                33000
# ..                                                 ...
# 134                                             941700
# 135                                            1095100
# 136                                            1197200
# 137                                            2463000
# 138                                            2189300
#
#      95% Lower confidence/credible interval for number  \
# 0                                                94000
# 1                                                85000
# 2                                                62000
# 3                                                25000
# 4                                                14000
# ..                                                 ...
# 134                                             874100
# 135                                            1022000
# 136                                            1135000
# 137                                            2338700
# 138                                            2094800
#
#      95% Upper confidence/credible interval for number  \
# 0                                               222000
# 1                                               208000
# 2                                               250000
# 3                                                99000
# 4                                                68000
# ..                                                 ...
# 134                                            1013600
# 135                                            1173500
# 136                                            1263900
# 137                                            2593200
# 138                                            2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 2                                             1 in 420
# 3                                           1 in 1,000
# 4                                           1 in 1,700
# ..                                                 ...
# 134                                            1 in 60
# 135                                            1 in 50
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 2                                           1 in 910
# 3                                         1 in 2,000
# 4                                         1 in 5,000
# ..                                               ...
# 134                                          1 in 60
# 135                                          1 in 55
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio start_date  \
# 0                                           1 in 240 2020-04-27
# 1                                           1 in 260 2020-05-04
# 2                                           1 in 220 2020-05-11
# 3                                           1 in 560 2020-05-17
# 4                                           1 in 830 2020-05-25
# ..                                               ...        ...
# 134                                          1 in 55 2022-11-20
# 135                                          1 in 45 2022-11-29
# 136                                          1 in 45 2022-12-03
# 137                                          1 in 20 2022-12-22
# 138                                          1 in 25 2022-12-28
#
#              end_date  start_date_year  start_date_week
# 0         10 May 2020             2020               18
# 1         17 May 2020             2020               19
# 2         24 May 2020             2020               20
# 3         30 May 2020             2020               20
# 4        07 June 2020             2020               22
# ..                ...              ...              ...
# 134  26 November 2022             2022               46
# 135  05 December 2022             2022               48
# 136  09 December 2022             2022               48
# 137  28 December 2022             2022               51
# 138   03 January 2023             2022               52
#
# [139 rows x 14 columns]

# %%
df2["start_date_year"].astype("str")
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 134    2022
# 135    2022
# 136    2022
# 137    2022
# 138    2022
# Name: start_date_year, Length: 139, dtype: object

# %%
df2["start_date_year"] = df2["start_date_year"].astype("str")

# %%
df2["start_date_week"] = df2["start_date_week"].astype("str")

# %%
df2["start_date_year"].str.cat(df2["start_date_week"].str, sep="-")
# Out:
# /Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/strings/accessor.py:393: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   others = list(others)  # ensure iterators do not get read twice etc
# 0      2020-1-8
# 1      2020-1-9
# 2      2020-2-0
# 3      2020-2-0
# 4      2020-2-2
#          ...
# 134    2022-4-6
# 135    2022-4-8
# 136    2022-4-8
# 137    2022-5-1
# 138    2022-5-2
# Name: start_date_year, Length: 139, dtype: object

# %%
df2["start_date_week"]
# Out:
# 0      18
# 1      19
# 2      20
# 3      20
# 4      22
#        ..
# 134    46
# 135    48
# 136    48
# 137    51
# 138    52
# Name: start_date_week, Length: 139, dtype: object

# %%
df2["week"] = df2["start_date_year"].str.cat(df2["start_date_week"], sep="-W")

# %%
df2
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 3              17 May 2020 to 30 May 2020                0.10
# 5             31 May 2020 to 13 June 2020                0.06
# 7            14 June 2020 to 27 June 2020                0.04
# ..                                    ...                 ...
# 132  09 November 2022 to 15 November 2022                1.48
# 134  20 November 2022 to 26 November 2022                1.73
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# 1                      0.16                    0.38   137000        85000
# 3                      0.05                    0.18    53000        25000
# 5                      0.02                    0.13    33000        12000
# 7                      0.02                    0.08    25000        12000
# ..                      ...                     ...      ...          ...
# 132                    1.39                    1.58   809200       757900
# 134                    1.60                    1.86   941700       874100
# 136                    2.08                    2.32  1197200      1135000
# 137                    4.29                    4.76  2463000      2338700
# 138                    3.84                    4.19  2189300      2094800
#
#      pop_est_uci  \
# 0         222000
# 1         208000
# 3          99000
# 5          74000
# 7          44000
# ..           ...
# 132       862600
# 134      1013600
# 136      1263900
# 137      2593200
# 138      2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 3                                           1 in 1,000
# 5                                           1 in 1,700
# 7                                           1 in 2,500
# ..                                                 ...
# 132                                            1 in 65
# 134                                            1 in 60
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 3                                         1 in 2,000
# 5                                         1 in 5,000
# 7                                         1 in 5,000
# ..                                               ...
# 132                                          1 in 70
# 134                                          1 in 60
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio start_date  \
# 0                                           1 in 240 2020-04-27
# 1                                           1 in 260 2020-05-04
# 3                                           1 in 560 2020-05-17
# 5                                           1 in 770 2020-05-31
# 7                                         1 in 1,300 2020-06-14
# ..                                               ...        ...
# 132                                          1 in 65 2022-11-09
# 134                                          1 in 55 2022-11-20
# 136                                          1 in 45 2022-12-03
# 137                                          1 in 20 2022-12-22
# 138                                          1 in 25 2022-12-28
#
#              end_date start_date_year start_date_week      week ons_geog_code
# 0         10 May 2020            2020              18  2020-W18     E92000001
# 1         17 May 2020            2020              19  2020-W19     E92000001
# 3         30 May 2020            2020              20  2020-W20     E92000001
# 5        13 June 2020            2020              22  2020-W22     E92000001
# 7        27 June 2020            2020              24  2020-W24     E92000001
# ..                ...             ...             ...       ...           ...
# 132  15 November 2022            2022              45  2022-W45     E92000001
# 134  26 November 2022            2022              46  2022-W46     E92000001
# 136  09 December 2022            2022              48  2022-W48     E92000001
# 137  28 December 2022            2022              51  2022-W51     E92000001
# 138   03 January 2023            2022              52  2022-W52     E92000001
#
# [130 rows x 16 columns]

# %%
{"Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",}
# Out:
# {'Estimated average % of the population testing positive for COVID-19': 'percentage_pop_est'}

# %%
{   "Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    "Estimated average % of the population testing positive for COVID-19": "percentage_pop_est_lci"

}
# Out:
# {'Estimated average % of the population testing positive for COVID-19': 'percentage_pop_est_lci'}

# %%
{   "Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    "95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    "95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    "Estimated average number of people testing positive for COVID-19": "pop_est",
    "95% Lower confidence/credible interval for number": "pop_est_lci",
    "95% Upper confidence/credible interval for number": "pop_est_uci",
}
# Out:
# {'Estimated average % of the population testing positive for COVID-19': 'percentage_pop_est',
#  '95% Lower confidence/credible interval for percentage': 'percentage_pop_est_lci',
#  '95% Upper confidence/credible interval for percentage': 'percentage_pop_est_uci',
#  'Estimated average number of people testing positive for COVID-19': 'pop_est',
#  '95% Lower confidence/credible interval for number': 'pop_est_lci',
#  '95% Upper confidence/credible interval for number': 'pop_est_uci'}

# %%
rename_columns = {   "Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    "95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    "95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    "Estimated average number of people testing positive for COVID-19": "pop_est",
    "95% Lower confidence/credible interval for number": "pop_est_lci",
    "95% Upper confidence/credible interval for number": "pop_est_uci",
}

# %%
df2.rename(columns=rename_columns)
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 3              17 May 2020 to 30 May 2020                0.10
# 5             31 May 2020 to 13 June 2020                0.06
# 7            14 June 2020 to 27 June 2020                0.04
# ..                                    ...                 ...
# 132  09 November 2022 to 15 November 2022                1.48
# 134  20 November 2022 to 26 November 2022                1.73
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# 1                      0.16                    0.38   137000        85000
# 3                      0.05                    0.18    53000        25000
# 5                      0.02                    0.13    33000        12000
# 7                      0.02                    0.08    25000        12000
# ..                      ...                     ...      ...          ...
# 132                    1.39                    1.58   809200       757900
# 134                    1.60                    1.86   941700       874100
# 136                    2.08                    2.32  1197200      1135000
# 137                    4.29                    4.76  2463000      2338700
# 138                    3.84                    4.19  2189300      2094800
#
#      pop_est_uci  \
# 0         222000
# 1         208000
# 3          99000
# 5          74000
# 7          44000
# ..           ...
# 132       862600
# 134      1013600
# 136      1263900
# 137      2593200
# 138      2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 3                                           1 in 1,000
# 5                                           1 in 1,700
# 7                                           1 in 2,500
# ..                                                 ...
# 132                                            1 in 65
# 134                                            1 in 60
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 3                                         1 in 2,000
# 5                                         1 in 5,000
# 7                                         1 in 5,000
# ..                                               ...
# 132                                          1 in 70
# 134                                          1 in 60
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio start_date  \
# 0                                           1 in 240 2020-04-27
# 1                                           1 in 260 2020-05-04
# 3                                           1 in 560 2020-05-17
# 5                                           1 in 770 2020-05-31
# 7                                         1 in 1,300 2020-06-14
# ..                                               ...        ...
# 132                                          1 in 65 2022-11-09
# 134                                          1 in 55 2022-11-20
# 136                                          1 in 45 2022-12-03
# 137                                          1 in 20 2022-12-22
# 138                                          1 in 25 2022-12-28
#
#              end_date start_date_year start_date_week      week ons_geog_code
# 0         10 May 2020            2020              18  2020-W18     E92000001
# 1         17 May 2020            2020              19  2020-W19     E92000001
# 3         30 May 2020            2020              20  2020-W20     E92000001
# 5        13 June 2020            2020              22  2020-W22     E92000001
# 7        27 June 2020            2020              24  2020-W24     E92000001
# ..                ...             ...             ...       ...           ...
# 132  15 November 2022            2022              45  2022-W45     E92000001
# 134  26 November 2022            2022              46  2022-W46     E92000001
# 136  09 December 2022            2022              48  2022-W48     E92000001
# 137  28 December 2022            2022              51  2022-W51     E92000001
# 138   03 January 2023            2022              52  2022-W52     E92000001
#
# [130 rows x 16 columns]

# %%
rename_columns = {   r"Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    "95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    "95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    "Estimated average number of people testing positive for COVID-19": "pop_est",
    "95% Lower confidence/credible interval for number": "pop_est_lci",
    "95% Upper confidence/credible interval for number": "pop_est_uci",
}

# %%
df2.rename(columns=rename_columns)
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 3              17 May 2020 to 30 May 2020                0.10
# 5             31 May 2020 to 13 June 2020                0.06
# 7            14 June 2020 to 27 June 2020                0.04
# ..                                    ...                 ...
# 132  09 November 2022 to 15 November 2022                1.48
# 134  20 November 2022 to 26 November 2022                1.73
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# 1                      0.16                    0.38   137000        85000
# 3                      0.05                    0.18    53000        25000
# 5                      0.02                    0.13    33000        12000
# 7                      0.02                    0.08    25000        12000
# ..                      ...                     ...      ...          ...
# 132                    1.39                    1.58   809200       757900
# 134                    1.60                    1.86   941700       874100
# 136                    2.08                    2.32  1197200      1135000
# 137                    4.29                    4.76  2463000      2338700
# 138                    3.84                    4.19  2189300      2094800
#
#      pop_est_uci  \
# 0         222000
# 1         208000
# 3          99000
# 5          74000
# 7          44000
# ..           ...
# 132       862600
# 134      1013600
# 136      1263900
# 137      2593200
# 138      2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 3                                           1 in 1,000
# 5                                           1 in 1,700
# 7                                           1 in 2,500
# ..                                                 ...
# 132                                            1 in 65
# 134                                            1 in 60
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 3                                         1 in 2,000
# 5                                         1 in 5,000
# 7                                         1 in 5,000
# ..                                               ...
# 132                                          1 in 70
# 134                                          1 in 60
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio start_date  \
# 0                                           1 in 240 2020-04-27
# 1                                           1 in 260 2020-05-04
# 3                                           1 in 560 2020-05-17
# 5                                           1 in 770 2020-05-31
# 7                                         1 in 1,300 2020-06-14
# ..                                               ...        ...
# 132                                          1 in 65 2022-11-09
# 134                                          1 in 55 2022-11-20
# 136                                          1 in 45 2022-12-03
# 137                                          1 in 20 2022-12-22
# 138                                          1 in 25 2022-12-28
#
#              end_date start_date_year start_date_week      week ons_geog_code
# 0         10 May 2020            2020              18  2020-W18     E92000001
# 1         17 May 2020            2020              19  2020-W19     E92000001
# 3         30 May 2020            2020              20  2020-W20     E92000001
# 5        13 June 2020            2020              22  2020-W22     E92000001
# 7        27 June 2020            2020              24  2020-W24     E92000001
# ..                ...             ...             ...       ...           ...
# 132  15 November 2022            2022              45  2022-W45     E92000001
# 134  26 November 2022            2022              46  2022-W46     E92000001
# 136  09 December 2022            2022              48  2022-W48     E92000001
# 137  28 December 2022            2022              51  2022-W51     E92000001
# 138   03 January 2023            2022              52  2022-W52     E92000001
#
# [130 rows x 16 columns]

# %%
rename_columns = {   r"Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    r"95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    r"95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    r"Estimated average number of people testing positive for COVID-19": "pop_est",
    r"95% Lower confidence/credible interval for number": "pop_est_lci",
    r"95% Upper confidence/credible interval for number": "pop_est_uci",
}

# %%
df2.rename(columns=rename_columns)
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 3              17 May 2020 to 30 May 2020                0.10
# 5             31 May 2020 to 13 June 2020                0.06
# 7            14 June 2020 to 27 June 2020                0.04
# ..                                    ...                 ...
# 132  09 November 2022 to 15 November 2022                1.48
# 134  20 November 2022 to 26 November 2022                1.73
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# 1                      0.16                    0.38   137000        85000
# 3                      0.05                    0.18    53000        25000
# 5                      0.02                    0.13    33000        12000
# 7                      0.02                    0.08    25000        12000
# ..                      ...                     ...      ...          ...
# 132                    1.39                    1.58   809200       757900
# 134                    1.60                    1.86   941700       874100
# 136                    2.08                    2.32  1197200      1135000
# 137                    4.29                    4.76  2463000      2338700
# 138                    3.84                    4.19  2189300      2094800
#
#      pop_est_uci  \
# 0         222000
# 1         208000
# 3          99000
# 5          74000
# 7          44000
# ..           ...
# 132       862600
# 134      1013600
# 136      1263900
# 137      2593200
# 138      2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 3                                           1 in 1,000
# 5                                           1 in 1,700
# 7                                           1 in 2,500
# ..                                                 ...
# 132                                            1 in 65
# 134                                            1 in 60
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 3                                         1 in 2,000
# 5                                         1 in 5,000
# 7                                         1 in 5,000
# ..                                               ...
# 132                                          1 in 70
# 134                                          1 in 60
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio start_date  \
# 0                                           1 in 240 2020-04-27
# 1                                           1 in 260 2020-05-04
# 3                                           1 in 560 2020-05-17
# 5                                           1 in 770 2020-05-31
# 7                                         1 in 1,300 2020-06-14
# ..                                               ...        ...
# 132                                          1 in 65 2022-11-09
# 134                                          1 in 55 2022-11-20
# 136                                          1 in 45 2022-12-03
# 137                                          1 in 20 2022-12-22
# 138                                          1 in 25 2022-12-28
#
#              end_date start_date_year start_date_week      week ons_geog_code
# 0         10 May 2020            2020              18  2020-W18     E92000001
# 1         17 May 2020            2020              19  2020-W19     E92000001
# 3         30 May 2020            2020              20  2020-W20     E92000001
# 5        13 June 2020            2020              22  2020-W22     E92000001
# 7        27 June 2020            2020              24  2020-W24     E92000001
# ..                ...             ...             ...       ...           ...
# 132  15 November 2022            2022              45  2022-W45     E92000001
# 134  26 November 2022            2022              46  2022-W46     E92000001
# 136  09 December 2022            2022              48  2022-W48     E92000001
# 137  28 December 2022            2022              51  2022-W51     E92000001
# 138   03 January 2023            2022              52  2022-W52     E92000001
#
# [130 rows x 16 columns]

# %%
df2.columns
# Out:
# Index(['Time period', 'percentage_pop_est', 'percentage_pop_est_lci',
#        'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci',
#        'Estimated average ratio of the population testing positive for COVID-19',
#        '95% Lower confidence/credible interval for ratio',
#        '95% Upper confidence/credible interval for ratio', 'start_date',
#        'end_date', 'start_date_year', 'start_date_week', 'week',
#        'ons_geog_code'],
#       dtype='object')

# %%
rename_columns = {   r"Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    r"95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    r"95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    r" Estimated average number of people testing positive for COVID-19": "pop_est",
    r"95% Lower confidence/credible interval for number": "pop_est_lci",
    r"95% Upper confidence/credible interval for number": "pop_est_uci",
}

# %%
df2.rename(columns=rename_columns)
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 3              17 May 2020 to 30 May 2020                0.10
# 5             31 May 2020 to 13 June 2020                0.06
# 7            14 June 2020 to 27 June 2020                0.04
# ..                                    ...                 ...
# 132  09 November 2022 to 15 November 2022                1.48
# 134  20 November 2022 to 26 November 2022                1.73
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# 1                      0.16                    0.38   137000        85000
# 3                      0.05                    0.18    53000        25000
# 5                      0.02                    0.13    33000        12000
# 7                      0.02                    0.08    25000        12000
# ..                      ...                     ...      ...          ...
# 132                    1.39                    1.58   809200       757900
# 134                    1.60                    1.86   941700       874100
# 136                    2.08                    2.32  1197200      1135000
# 137                    4.29                    4.76  2463000      2338700
# 138                    3.84                    4.19  2189300      2094800
#
#      pop_est_uci  \
# 0         222000
# 1         208000
# 3          99000
# 5          74000
# 7          44000
# ..           ...
# 132       862600
# 134      1013600
# 136      1263900
# 137      2593200
# 138      2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 3                                           1 in 1,000
# 5                                           1 in 1,700
# 7                                           1 in 2,500
# ..                                                 ...
# 132                                            1 in 65
# 134                                            1 in 60
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 3                                         1 in 2,000
# 5                                         1 in 5,000
# 7                                         1 in 5,000
# ..                                               ...
# 132                                          1 in 70
# 134                                          1 in 60
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio start_date  \
# 0                                           1 in 240 2020-04-27
# 1                                           1 in 260 2020-05-04
# 3                                           1 in 560 2020-05-17
# 5                                           1 in 770 2020-05-31
# 7                                         1 in 1,300 2020-06-14
# ..                                               ...        ...
# 132                                          1 in 65 2022-11-09
# 134                                          1 in 55 2022-11-20
# 136                                          1 in 45 2022-12-03
# 137                                          1 in 20 2022-12-22
# 138                                          1 in 25 2022-12-28
#
#              end_date start_date_year start_date_week      week ons_geog_code
# 0         10 May 2020            2020              18  2020-W18     E92000001
# 1         17 May 2020            2020              19  2020-W19     E92000001
# 3         30 May 2020            2020              20  2020-W20     E92000001
# 5        13 June 2020            2020              22  2020-W22     E92000001
# 7        27 June 2020            2020              24  2020-W24     E92000001
# ..                ...             ...             ...       ...           ...
# 132  15 November 2022            2022              45  2022-W45     E92000001
# 134  26 November 2022            2022              46  2022-W46     E92000001
# 136  09 December 2022            2022              48  2022-W48     E92000001
# 137  28 December 2022            2022              51  2022-W51     E92000001
# 138   03 January 2023            2022              52  2022-W52     E92000001
#
# [130 rows x 16 columns]

# %%
df2 = df2.rename(columns=rename_columns)

# %%
df2
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 3              17 May 2020 to 30 May 2020                0.10
# 5             31 May 2020 to 13 June 2020                0.06
# 7            14 June 2020 to 27 June 2020                0.04
# ..                                    ...                 ...
# 132  09 November 2022 to 15 November 2022                1.48
# 134  20 November 2022 to 26 November 2022                1.73
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# 1                      0.16                    0.38   137000        85000
# 3                      0.05                    0.18    53000        25000
# 5                      0.02                    0.13    33000        12000
# 7                      0.02                    0.08    25000        12000
# ..                      ...                     ...      ...          ...
# 132                    1.39                    1.58   809200       757900
# 134                    1.60                    1.86   941700       874100
# 136                    2.08                    2.32  1197200      1135000
# 137                    4.29                    4.76  2463000      2338700
# 138                    3.84                    4.19  2189300      2094800
#
#      pop_est_uci  \
# 0         222000
# 1         208000
# 3          99000
# 5          74000
# 7          44000
# ..           ...
# 132       862600
# 134      1013600
# 136      1263900
# 137      2593200
# 138      2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 3                                           1 in 1,000
# 5                                           1 in 1,700
# 7                                           1 in 2,500
# ..                                                 ...
# 132                                            1 in 65
# 134                                            1 in 60
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 3                                         1 in 2,000
# 5                                         1 in 5,000
# 7                                         1 in 5,000
# ..                                               ...
# 132                                          1 in 70
# 134                                          1 in 60
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio start_date  \
# 0                                           1 in 240 2020-04-27
# 1                                           1 in 260 2020-05-04
# 3                                           1 in 560 2020-05-17
# 5                                           1 in 770 2020-05-31
# 7                                         1 in 1,300 2020-06-14
# ..                                               ...        ...
# 132                                          1 in 65 2022-11-09
# 134                                          1 in 55 2022-11-20
# 136                                          1 in 45 2022-12-03
# 137                                          1 in 20 2022-12-22
# 138                                          1 in 25 2022-12-28
#
#              end_date start_date_year start_date_week      week ons_geog_code
# 0         10 May 2020            2020              18  2020-W18     E92000001
# 1         17 May 2020            2020              19  2020-W19     E92000001
# 3         30 May 2020            2020              20  2020-W20     E92000001
# 5        13 June 2020            2020              22  2020-W22     E92000001
# 7        27 June 2020            2020              24  2020-W24     E92000001
# ..                ...             ...             ...       ...           ...
# 132  15 November 2022            2022              45  2022-W45     E92000001
# 134  26 November 2022            2022              46  2022-W46     E92000001
# 136  09 December 2022            2022              48  2022-W48     E92000001
# 137  28 December 2022            2022              51  2022-W51     E92000001
# 138   03 January 2023            2022              52  2022-W52     E92000001
#
# [130 rows x 16 columns]

# %%
df2.columns
# Out:
# Index(['Time period', 'percentage_pop_est', 'percentage_pop_est_lci',
#        'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci',
#        'Estimated average ratio of the population testing positive for COVID-19',
#        '95% Lower confidence/credible interval for ratio',
#        '95% Upper confidence/credible interval for ratio', 'start_date',
#        'end_date', 'start_date_year', 'start_date_week', 'week',
#        'ons_geog_code'],
#       dtype='object')

# %%
df2[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
# Out:
#          week  percentage_pop_est  percentage_pop_est_lci  \
# 0    2020-W18                0.27                    0.17
# 1    2020-W19                0.25                    0.16
# 3    2020-W20                0.10                    0.05
# 5    2020-W22                0.06                    0.02
# 7    2020-W24                0.04                    0.02
# ..        ...                 ...                     ...
# 132  2022-W45                1.48                    1.39
# 134  2022-W46                1.73                    1.60
# 136  2022-W48                2.20                    2.08
# 137  2022-W51                4.52                    4.29
# 138  2022-W52                4.02                    3.84
#
#      percentage_pop_est_uci  pop_est  pop_est_lci  pop_est_uci
# 0                      0.41   148000        94000       222000
# 1                      0.38   137000        85000       208000
# 3                      0.18    53000        25000        99000
# 5                      0.13    33000        12000        74000
# 7                      0.08    25000        12000        44000
# ..                      ...      ...          ...          ...
# 132                    1.58   809200       757900       862600
# 134                    1.86   941700       874100      1013600
# 136                    2.32  1197200      1135000      1263900
# 137                    4.76  2463000      2338700      2593200
# 138                    4.19  2189300      2094800      2283200
#
# [130 rows x 7 columns]

# %%
df2[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
# Out:
#          week  percentage_pop_est  percentage_pop_est_lci  \
# 0    2020-W18                0.27                    0.17
# 1    2020-W19                0.25                    0.16
# 3    2020-W20                0.10                    0.05
# 5    2020-W22                0.06                    0.02
# 7    2020-W24                0.04                    0.02
# ..        ...                 ...                     ...
# 132  2022-W45                1.48                    1.39
# 134  2022-W46                1.73                    1.60
# 136  2022-W48                2.20                    2.08
# 137  2022-W51                4.52                    4.29
# 138  2022-W52                4.02                    3.84
#
#      percentage_pop_est_uci  pop_est  pop_est_lci  pop_est_uci
# 0                      0.41   148000        94000       222000
# 1                      0.38   137000        85000       208000
# 3                      0.18    53000        25000        99000
# 5                      0.13    33000        12000        74000
# 7                      0.08    25000        12000        44000
# ..                      ...      ...          ...          ...
# 132                    1.58   809200       757900       862600
# 134                    1.86   941700       874100      1013600
# 136                    2.32  1197200      1135000      1263900
# 137                    4.76  2463000      2338700      2593200
# 138                    4.19  2189300      2094800      2283200
#
# [130 rows x 7 columns]

# %%
df2[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']].to_csv("20230113covid19infectionsurveydatasetengland_sheet1a.csv",index=False)

# %%
df2["ons_geog_code"] = "E92000001"

# %%
df2
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 3              17 May 2020 to 30 May 2020                0.10
# 5             31 May 2020 to 13 June 2020                0.06
# 7            14 June 2020 to 27 June 2020                0.04
# ..                                    ...                 ...
# 132  09 November 2022 to 15 November 2022                1.48
# 134  20 November 2022 to 26 November 2022                1.73
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# 1                      0.16                    0.38   137000        85000
# 3                      0.05                    0.18    53000        25000
# 5                      0.02                    0.13    33000        12000
# 7                      0.02                    0.08    25000        12000
# ..                      ...                     ...      ...          ...
# 132                    1.39                    1.58   809200       757900
# 134                    1.60                    1.86   941700       874100
# 136                    2.08                    2.32  1197200      1135000
# 137                    4.29                    4.76  2463000      2338700
# 138                    3.84                    4.19  2189300      2094800
#
#      pop_est_uci  \
# 0         222000
# 1         208000
# 3          99000
# 5          74000
# 7          44000
# ..           ...
# 132       862600
# 134      1013600
# 136      1263900
# 137      2593200
# 138      2283200
#
#     Estimated average ratio of the population testing positive for COVID-19  \
# 0                                             1 in 370
# 1                                             1 in 400
# 3                                           1 in 1,000
# 5                                           1 in 1,700
# 7                                           1 in 2,500
# ..                                                 ...
# 132                                            1 in 65
# 134                                            1 in 60
# 136                                            1 in 45
# 137                                            1 in 20
# 138                                            1 in 25
#
#     95% Lower confidence/credible interval for ratio  \
# 0                                           1 in 590
# 1                                           1 in 630
# 3                                         1 in 2,000
# 5                                         1 in 5,000
# 7                                         1 in 5,000
# ..                                               ...
# 132                                          1 in 70
# 134                                          1 in 60
# 136                                          1 in 50
# 137                                          1 in 25
# 138                                          1 in 25
#
#     95% Upper confidence/credible interval for ratio start_date  \
# 0                                           1 in 240 2020-04-27
# 1                                           1 in 260 2020-05-04
# 3                                           1 in 560 2020-05-17
# 5                                           1 in 770 2020-05-31
# 7                                         1 in 1,300 2020-06-14
# ..                                               ...        ...
# 132                                          1 in 65 2022-11-09
# 134                                          1 in 55 2022-11-20
# 136                                          1 in 45 2022-12-03
# 137                                          1 in 20 2022-12-22
# 138                                          1 in 25 2022-12-28
#
#              end_date start_date_year start_date_week      week ons_geog_code
# 0         10 May 2020            2020              18  2020-W18     E92000001
# 1         17 May 2020            2020              19  2020-W19     E92000001
# 3         30 May 2020            2020              20  2020-W20     E92000001
# 5        13 June 2020            2020              22  2020-W22     E92000001
# 7        27 June 2020            2020              24  2020-W24     E92000001
# ..                ...             ...             ...       ...           ...
# 132  15 November 2022            2022              45  2022-W45     E92000001
# 134  26 November 2022            2022              46  2022-W46     E92000001
# 136  09 December 2022            2022              48  2022-W48     E92000001
# 137  28 December 2022            2022              51  2022-W51     E92000001
# 138   03 January 2023            2022              52  2022-W52     E92000001
#
# [130 rows x 16 columns]

# %%
df2.drop_duplicates(subset="week", keep="last", inplace=True)

# %%
df2[["week", "ons_geog_code", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']].to_csv("20230113covid19infectionsurveydatasetengland_sheet1a.csv",index=False)
